# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load cleaned dataset
df = pd.read_csv("../output/reports/cleaned_telecom_data.csv")

# Show first rows
df.head()
# Out:
#   radio  MCC  MNC    TAC    CID  unit        LON        LAT  RANGE  SAM  \
# 0   GSM  602    3  21333  25372     0  31.056510  29.998215  23897   10
# 1   GSM  602    3  21362  23224     0  31.373520  29.839554   1000    4
# 2   GSM  602    3  22533   5031     0  31.160660  29.998856   1000    1
# 3   GSM  602    3  22202  40686     0  31.501236  30.592117   1000    1
# 4   GSM  602    3  21333  25376     0  31.277390  30.095673   1000    2
#
#    changeable     created     updated  averageSignal Country   Network  \
# 0           1  1459715136  1465348064              0   Egypt  Etisalat
# 1           1  1459813831  1474212997              0   Egypt  Etisalat
# 2           1  1459695955  1459695955              0   Egypt  Etisalat
# 3           1  1459681907  1459681907              0   Egypt  Etisalat
# 4           1  1459715136  1460478702              0   Egypt  Etisalat
#
#   Continent
# 0    Africa
# 1    Africa
# 2    Africa
# 3    Africa
# 4    Africa

# %%
df.shape

# %%
df.isnull().sum()
# Out:
# radio            0
# MCC              0
# MNC              0
# TAC              0
# CID              0
# unit             0
# LON              0
# LAT              0
# RANGE            0
# SAM              0
# changeable       0
# created          0
# updated          0
# averageSignal    0
# Country          0
# Network          0
# Continent        0
# dtype: int64

# %%
network_counts = df["Network"].value_counts()

plt.figure(figsize=(10,6))

network_counts.plot(kind="bar")

plt.title("Network Distribution")

plt.show()

# %%
network_counts = df["Network"].value_counts()

plt.figure(figsize=(10,6))

network_counts.plot(kind="bar")

plt.title("Network Distribution")

plt.show()  # Add this line to display the plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 network_counts = df["Network"].value_counts()
#       3 plt.figure(figsize=(10,6))
#       5 network_counts.plot(kind="bar")
#
# NameError: name 'df' is not defined
